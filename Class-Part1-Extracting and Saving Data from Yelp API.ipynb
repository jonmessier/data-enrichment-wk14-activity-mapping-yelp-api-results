# %% [markdown]
# # Part 1 - Extracting and Saving Data from Yelp API

# %% [markdown]
# ## Obective

# %% [markdown]
# - For this CodeAlong, we will be working with the Yelp API.
# - You will use the the Yelp API to search your home town for a cuisine type of your choice.
# - Next class, we will then use Plotly Express to create a map with the Mapbox API to visualize the results.

# %% [markdown]
# ## Tools You Will Use
# - Part 1:
#     - Yelp API:
#         - Getting Started:
#             - https://www.yelp.com/developers/documentation/v3/get_started
#
#     - `YelpAPI` python package
#         -  "YelpAPI": https://github.com/gfairchild/yelpapi
# - Part 2:
#
#     - Plotly Express: https://plotly.com/python/getting-started/
#         - With Mapbox API: https://www.mapbox.com/
#         - `px.scatter_mapbox` [Documentation](https://plotly.com/python/scattermapbox/):

# %% [markdown]
# ### Applying Code From
# - Efficient API Calls Lesson Link: https://login.codingdojo.com/m/376/12529/88078

# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Additional Imports
import os, json, math, time
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook

# %%
#!pip install yelpapi

# %% [markdown]
# ## 1. Registering for Required APIs

# %% [markdown]
# - Yelp: https://www.yelp.com/developers/documentation/v3/get_started

# %% [markdown]
# > Check the official API documentation to know what arguments we can search for: https://www.yelp.com/developers/documentation/v3/business_search

# %% [markdown]
# ### Load Credentials and Create Yelp API Object

# %%
# Load API Credentials
with open('/Users/jonme/.secret/yelp_api.json','r') as f:
    login = json.load(f)

# %%
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
# Instantiate YelpAPI Variable
yelp = YelpAPI(login['api-key'],timeout_s=5.0)

# %% [markdown]
# ### Define Search Terms and File Paths

# %%
# set our API call parameters and filename before the first call
location = 'Minneapolis, MN'
term = 'pizza'

# %%
location.split(',')[0]
# Out:
# 'Minneapolis'

# %%
## Specify fodler for saving data
FOLDER ='Data/'

os.makedirs(FOLDER,exist_ok=True)

# Specifying JSON_FILE filename (can include a folder)
JSON_FILE = FOLDER+f"{location.split(',')[0]}-{term}.json"

# %%
JSON_FILE
# Out:
# 'Data/Minneapolis-pizza.json'

# %% [markdown]
# ### Check if Json File exists and Create it if it doesn't

# %%
## Check if JSON_FILE exists
file_exists = os.path.isfile(JSON_FILE)

## If it does not exist: 
if file_exists ==False:
    ## CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    
    ## If JSON_FILE included a folder:
    if len(folder)>0:
        # create the folder
        os.makedirs(folder,exist_ok=True)
        
    ## INFORM USER AND SAVE EMPTY LIST
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")
    
    
    ## save the first page of results
    with open(JSON_FILE,'w')as f:
        json.dump([],f)
        
## If it exists, inform user
else:
       print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/Minneapolis-pizza.json not found. Saving empty list to file.

# %% [markdown]
# ![png](Figures/question.png)

# %% [markdown]
# ### Make the first API call to get the first page of data

# %% [markdown]
# - We will use this first result to check:
#     - how many total results there are?
#     - Where is the actual data we want to save?
#     - how many results do we get at a time?

# %%
# use our yelp_api variable's search_query method to perform our API call
results = yelp.search_query(term=term,location = location)

# %%
type(results)
# Out:
# dict

# %%
len(results)
# Out:
# 3

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['total']
# Out:
# 1700

# %%
results['region']
# Out:
# {'center': {'longitude': -93.26156616210938, 'latitude': 44.97044244293755}}

# %%
results['businesses']
# Out:
# [{'id': 'iH3FcZ4Xchx3s7fgIINaYg',
#   'alias': 'pizzeria-lola-minneapolis',
#   'name': 'Pizzeria Lola',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hnnHp28kNSXxQXr20bAIbQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pizzeria-lola-minneapolis?adjust_creative=UC-A5xGcluPD3j5hJu71tw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UC-A5xGcluPD3j5hJu71tw',
#   'review_count': 1236,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 44.901815399420016,
#    'longitude': -93.31847304108392},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '5557 Xerxes Ave S',
#    'address2': '',
#    'address3': '',
#    'city': 'Minneapolis',
#    'zip_code': '55410',
#    'country': 'US',
#    'state': 'MN',
#    'display_address': ['5557 Xerxes Ave S', 'Minneapolis, MN 55410']},
#   'phone': '+16124248338',
#   'display_phone': '(612) 424-8338',
#   'distance': 8848.533353433979},
#  {'id': '5Y2nekkwRrNMMSx3b-2EhA',
#   'alias': 'young-joni-minneapolis',
#   'name': 'Young Joni',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0Js61iGwSbutQrcgAiuguQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/young-joni-minneapolis?adjust_creative=UC-A5xGcluPD3j5hJu71tw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UC-A5xGcluPD3j5hJu71tw',
#   'review_count': 909,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 45.00123, 'longitude': -93.26664},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '165 13th Ave NE',
#    'address2': '',
#    'address3': None,
#    'city': 'Minneapolis',
#    'zip_code': '55413',
#    'country': 'US',
#    'state': 'MN',
#    'display_address': ['165 13th Ave NE', 'Minneapolis, MN 55413']},
#   'phone': '+16123455719',
#   'display_phone': '(612) 345-5719',
#   'distance': 3427.201161197481},
#  {'id': 'H16j-AnU6QNcuNFgPNt2Sw',
#   'alias': 'pizza-lucé-downtown-minneapolis',
#   'name': 'Pizza Lucé Downtown',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/J48o_dqps_HYLO_R9-AG1Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pizza-luc%C3%A9-downtown-minneapolis?adjust_creative=UC-A5xGcluPD3j5hJu71tw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UC-A5xGcluPD3j5hJu71tw',
#   'review_count': 680,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 44.9817564, 'longitude': -93.2735524},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '119 N 4th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Minneapolis',
#    'zip_code': '55401',
#    'country': 'US',
#    'state': 'MN',
#    'display_address': ['119 N 4th St', 'Minneapolis, MN 55401']},
#   'phone': '+16123337359',
#   'display_phone': '(612) 333-7359',
#   'distance': 1572.1407878550754},
#  {'id': 'Z9UFvaj_zeaVSg4Ta8D9qQ',
#   'alias': 'red-rabbit-minneapolis',
#   'name': 'Red Rabbit',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/q_0dLYpK2q4-MI5YV93oFA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/red-rabbit-minneapolis?adjust_creative=UC-A5xGcluPD3j5hJu71tw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UC-A5xGcluPD3j5hJu71tw',
#   'review_count': 744,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 44.983694, 'longitude': -93.271747},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '201 N Washington Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Minneapolis',
#    'zip_code': '55401',
#    'country': 'US',
#    'state': 'MN',
#    'display_address': ['201 N Washington Ave', 'Minneapolis, MN 55401']},
#   'phone': '+16127678855',
#   'display_phone': '(612) 767-8855',
#   'distance': 1677.0520182434802},
#  {'id': '_-DCHZV7n1LzeD6cFVpebQ',
#   'alias': 'og-zaza-roseville',
#   'name': 'OG Zaza',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4MNgRAh1Sch2kcrbyuP0Fw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/og-zaza-roseville?adjust_creative=UC-A5xGcluPD3j5hJu71tw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UC-A5xGcluPD3j5hJu71tw',
#   'review_count': 7,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'desserts', 'title': 'Desserts'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 45.01285904350727, 'longitude': -93.1704907},
#   'transactions': [],
#   'location': {'address1': '1595 MN-36',
#    'address2': 'Ste 1030',
#    'address3': None,
#    'city': 'Roseville',
#    'zip_code': '55113',
#    'country': 'US',
#    'state': 'MN',
#    'display_address': ['1595 MN-36', 'Ste 1030', 'Roseville, MN 55113']},
#   'phone': '+16512075746',
#   'display_phone': '(651) 207-5746',
#   'distance': 8575.524206416143},
#  {'id': 'khPTVPMHdaAUNOX1LVnBng',
#   'alias': 'bricksworth-beer-co-minneapolis',
#   'name': 'Bricksworth Beer Co',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mRsAEDzIeM1-5-twue3-QA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bricksworth-beer-co-minneapolis?adjust_creative=UC-A5xGcluPD3j5hJu71tw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UC-A5xGcluPD3j5hJu71tw',
#   'review_count': 4,
#   'categories': [{'alias': 'brewpubs', 'title': 'Brewpubs'},
#    {'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 44.9848362, 'longitude': -93.27617409999999},
#   'transactions': [],
#   'location': {'address1': '305 N 5th Ave',
#    'address2': 'Ste 105',
#    'address3': None,
#    'city': 'Minneapolis',
#    'zip_code': '55401',
#    'country': 'US',
#    'state': 'MN',
#    'display_address': ['305 N 5th Ave', 'Ste 105', 'Minneapolis, MN 55401']},
#   'phone': '+19526575236',
#   'display_phone': '(952) 657-5236',
#   'distance': 1970.249685941049},
#  {'id': 'CSmr2eaOX3SDsL5htqIynw',
#   'alias': 'boludo-minneapolis-4',
#   'name': 'Boludo',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pSvuJREBQpROZ8SJowqm4w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/boludo-minneapolis-4?adjust_creative=UC-A5xGcluPD3j5hJu71tw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UC-A5xGcluPD3j5hJu71tw',
#   'review_count': 105,
#   'categories': [{'alias': 'argentine', 'title': 'Argentine'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 44.976956, 'longitude': -93.26202},
#   'transactions': ['delivery'],
#   'location': {'address1': '530 S 4th St',
#    'address2': None,
#    'address3': '',
#    'city': 'Minneapolis',
#    'zip_code': '55415',
#    'country': 'US',
#    'state': 'MN',
#    'display_address': ['530 S 4th St', 'Minneapolis, MN 55415']},
#   'phone': '+16124463833',
#   'display_phone': '(612) 446-3833',
#   'distance': 703.918303120063},
#  {'id': 'OXy8tz9HWiOK_fbh29TEGg',
#   'alias': 'boludo-minneapolis-3',
#   'name': 'Boludo ',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tgxeHCo89tbdtC-VWC0IIQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/boludo-minneapolis-3?adjust_creative=UC-A5xGcluPD3j5hJu71tw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UC-A5xGcluPD3j5hJu71tw',
#   'review_count': 321,
#   'categories': [{'alias': 'empanadas', 'title': 'Empanadas'},
#    {'alias': 'gluten_free', 'title': 'Gluten-Free'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 44.93427172240348, 'longitude': -93.2784959},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '8 W 38th St',
#    'address2': '',
#    'address3': None,
#    'city': 'Minneapolis',
#    'zip_code': '55409',
#    'country': 'US',
#    'state': 'MN',
#    'display_address': ['8 W 38th St', 'Minneapolis, MN 55409']},
#   'phone': '+16123535574',
#   'display_phone': '(612) 353-5574',
#   'distance': 4236.897520950619},
#  {'id': 'yUO_BhkMsv-oJdJDdi3UGw',
#   'alias': 'wrecktangle-pizza-minneapolis',
#   'name': 'Wrecktangle Pizza',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7qmBevP-5JMpi4rYScbpFw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/wrecktangle-pizza-minneapolis?adjust_creative=UC-A5xGcluPD3j5hJu71tw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UC-A5xGcluPD3j5hJu71tw',
#   'review_count': 99,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 44.98795, 'longitude': -93.27803},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '729 N Washington Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Minneapolis',
#    'zip_code': '55413',
#    'country': 'US',
#    'state': 'MN',
#    'display_address': ['729 N Washington Ave', 'Minneapolis, MN 55413']},
#   'phone': '+16126956525',
#   'display_phone': '(612) 695-6525',
#   'distance': 2340.875058885432},
#  {'id': 'BzB0KtBMoml85z9FEHtZzw',
#   'alias': 'italian-butcher-savage',
#   'name': 'Italian Butcher',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RFgr95LTrS64_E_Z9o5OQQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/italian-butcher-savage?adjust_creative=UC-A5xGcluPD3j5hJu71tw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UC-A5xGcluPD3j5hJu71tw',
#   'review_count': 2,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 44.7425923944024,
#    'longitude': -93.37908748537302},
#   'transactions': ['delivery'],
#   'location': {'address1': '14425 State Hwy 13',
#    'address2': '',
#    'address3': None,
#    'city': 'Savage',
#    'zip_code': '55378',
#    'country': 'US',
#    'state': 'MN',
#    'display_address': ['14425 State Hwy 13', 'Savage, MN 55378']},
#   'phone': '+19528554665',
#   'display_phone': '(952) 855-4665',
#   'distance': 26976.10322096065},
#  {'id': '8jLJGrAKL90O5z98ZNQ2bQ',
#   'alias': 'black-sheep-coal-fired-pizza-minneapolis',
#   'name': 'Black Sheep Coal Fired Pizza',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1XFLsW_xJTJ50U9r9s6lDQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/black-sheep-coal-fired-pizza-minneapolis?adjust_creative=UC-A5xGcluPD3j5hJu71tw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UC-A5xGcluPD3j5hJu71tw',
#   'review_count': 587,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 44.98728104723343,
#    'longitude': -93.27560096514135},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '600 Washington Ave N',
#    'address2': '',
#    'address3': None,
#    'city': 'Minneapolis',
#    'zip_code': '55401',
#    'country': 'US',
#    'state': 'MN',
#    'display_address': ['600 Washington Ave N', 'Minneapolis, MN 55401']},
#   'phone': '+16123422625',
#   'display_phone': '(612) 342-2625',
#   'distance': 2173.5643594342914},
#  {'id': 'DCgcpxRiguQkyYLoX-WAMg',
#   'alias': 'good-times-minneapolis',
#   'name': 'Good Times',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/keZl_xVkSypZlu_LJmUiFA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/good-times-minneapolis?adjust_creative=UC-A5xGcluPD3j5hJu71tw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UC-A5xGcluPD3j5hJu71tw',
#   'review_count': 17,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'salad', 'title': 'Salad'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 44.93423, 'longitude': -93.28399},
#   'transactions': [],
#   'location': {'address1': '322 W 38th St',
#    'address2': '',
#    'address3': None,
#    'city': 'Minneapolis',
#    'zip_code': '55409',
#    'country': 'US',
#    'state': 'MN',
#    'display_address': ['322 W 38th St', 'Minneapolis, MN 55409']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 4396.3077717375545},
#  {'id': '4MaXw1ibxnsqBem43kAm_Q',
#   'alias': 'pizzaria-novara-bloomington',
#   'name': 'Pizzaria Novara',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ErBjm3ANGwGwx2FdSZwpqw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pizzaria-novara-bloomington?adjust_creative=UC-A5xGcluPD3j5hJu71tw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UC-A5xGcluPD3j5hJu71tw',
#   'review_count': 8,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 44.85627992755595,
#    'longitude': -93.23696430298392},
#   'transactions': [],
#   'location': {'address1': '8100 26th Ave S',
#    'address2': '',
#    'address3': None,
#    'city': 'Bloomington',
#    'zip_code': '55425',
#    'country': 'US',
#    'state': 'MN',
#    'display_address': ['8100 26th Ave S', 'Bloomington, MN 55425']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 12841.252544377716},
#  {'id': '34MfK_IGLKnDju2cyRWUhw',
#   'alias': 'a-slice-of-new-york-minneapolis',
#   'name': 'A Slice of New York',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cEw9cQ6bi1x1aTAb1TQvJA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/a-slice-of-new-york-minneapolis?adjust_creative=UC-A5xGcluPD3j5hJu71tw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UC-A5xGcluPD3j5hJu71tw',
#   'review_count': 143,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 44.9589542099465,
#    'longitude': -93.2777589606123},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '2407 Nicollet Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Minneapolis',
#    'zip_code': '55404',
#    'country': 'US',
#    'state': 'MN',
#    'display_address': ['2407 Nicollet Ave', 'Minneapolis, MN 55404']},
#   'phone': '+16128714334',
#   'display_phone': '(612) 871-4334',
#   'distance': 1793.4823486251223},
#  {'id': 'XTD53AVRylnImME1acOTqg',
#   'alias': 'element-wood-fire-pizza-minneapolis',
#   'name': 'Element Wood Fire Pizza',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rpBdMYrCTU2ZZ9GFgYKaEw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/element-wood-fire-pizza-minneapolis?adjust_creative=UC-A5xGcluPD3j5hJu71tw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UC-A5xGcluPD3j5hJu71tw',
#   'review_count': 282,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 44.9986018, 'longitude': -93.2676826},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '96 Broadway St NE',
#    'address2': '',
#    'address3': '',
#    'city': 'Minneapolis',
#    'zip_code': '55413',
#    'country': 'US',
#    'state': 'MN',
#    'display_address': ['96 Broadway St NE', 'Minneapolis, MN 55413']},
#   'phone': '+16123793028',
#   'display_phone': '(612) 379-3028',
#   'distance': 3167.9102860812222},
#  {'id': 'SCMZp8X_XSTmiv783G-urg',
#   'alias': 'elmars-new-york-pizza-plymouth',
#   'name': "ElMar's New York Pizza",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SA723qGfNXkdIffI_ULObQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/elmars-new-york-pizza-plymouth?adjust_creative=UC-A5xGcluPD3j5hJu71tw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UC-A5xGcluPD3j5hJu71tw',
#   'review_count': 137,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 45.0235, 'longitude': -93.48097},
#   'transactions': ['delivery'],
#   'location': {'address1': '15725 37th Ave N',
#    'address2': '',
#    'address3': None,
#    'city': 'Plymouth',
#    'zip_code': '55446',
#    'country': 'US',
#    'state': 'MN',
#    'display_address': ['15725 37th Ave N', 'Plymouth, MN 55446']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 18261.30533219757},
#  {'id': 'MIko91ZaMFPwcUqGkK5iUQ',
#   'alias': 'broadway-pizza-richfield',
#   'name': 'Broadway Pizza',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ahisi4sHszxY_AFZW7bQcw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/broadway-pizza-richfield?adjust_creative=UC-A5xGcluPD3j5hJu71tw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UC-A5xGcluPD3j5hJu71tw',
#   'review_count': 169,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 44.86667, 'longitude': -93.28885},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '7514 Lyndale Ave S',
#    'address2': '',
#    'address3': '',
#    'city': 'Richfield',
#    'zip_code': '55423',
#    'country': 'US',
#    'state': 'MN',
#    'display_address': ['7514 Lyndale Ave S', 'Richfield, MN 55423']},
#   'phone': '+16128613402',
#   'display_phone': '(612) 861-3402',
#   'distance': 11737.08115856535},
#  {'id': 'mmWrP9IOhnJWs-rPKqJ_ww',
#   'alias': 'tono-pizzeria-cheesesteaks-saint-paul',
#   'name': 'Tono Pizzeria + Cheesesteaks',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/w216mYgQkDnGrxKajlZ09w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tono-pizzeria-cheesesteaks-saint-paul?adjust_creative=UC-A5xGcluPD3j5hJu71tw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UC-A5xGcluPD3j5hJu71tw',
#   'review_count': 83,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'cheesesteaks', 'title': 'Cheesesteaks'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 44.93409, 'longitude': -93.167325},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1580 Saint Clair Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Saint Paul',
#    'zip_code': '55105',
#    'country': 'US',
#    'state': 'MN',
#    'display_address': ['1580 Saint Clair Ave', 'Saint Paul, MN 55105']},
#   'phone': '+16512431978',
#   'display_phone': '(651) 243-1978',
#   'distance': 8446.51133865368},
#  {'id': '5wZrNeYwR-m_EiDrWro29w',
#   'alias': 'wrecktangle-pizza-minneapolis-2',
#   'name': 'Wrecktangle Pizza',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/K6kJgWr9Uk7kI9ZV9Cr9LA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/wrecktangle-pizza-minneapolis-2?adjust_creative=UC-A5xGcluPD3j5hJu71tw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UC-A5xGcluPD3j5hJu71tw',
#   'review_count': 26,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 44.948183772838064,
#    'longitude': -93.28842781484127},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '703 W Lake St',
#    'address2': '',
#    'address3': None,
#    'city': 'Minneapolis',
#    'zip_code': '55408',
#    'country': 'US',
#    'state': 'MN',
#    'display_address': ['703 W Lake St', 'Minneapolis, MN 55408']},
#   'phone': '+16124444420',
#   'display_phone': '(612) 444-4420',
#   'distance': 3254.675792416654},
#  {'id': '9GYDp5N1RljwT9kNw326MA',
#   'alias': 'arturos-pizza-minneapolis',
#   'name': "Arturo's Pizza",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kXqlImV4FLc3jxpYleMaMQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/arturos-pizza-minneapolis?adjust_creative=UC-A5xGcluPD3j5hJu71tw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UC-A5xGcluPD3j5hJu71tw',
#   'review_count': 12,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'desserts', 'title': 'Desserts'},
#    {'alias': 'salad', 'title': 'Salad'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 44.988530729766985,
#    'longitude': -93.25694459824238},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '18 University Ave NE',
#    'address2': None,
#    'address3': '',
#    'city': 'Minneapolis',
#    'zip_code': '55413',
#    'country': 'US',
#    'state': 'MN',
#    'display_address': ['18 University Ave NE', 'Minneapolis, MN 55413']},
#   'phone': '+16128861624',
#   'display_phone': '(612) 886-1624',
#   'distance': 2043.9080740987886}]

# %%
pd.DataFrame(results['businesses'])
# Out:
#                         id                                     alias  \
# 0   iH3FcZ4Xchx3s7fgIINaYg                 pizzeria-lola-minneapolis
# 1   5Y2nekkwRrNMMSx3b-2EhA                    young-joni-minneapolis
# 2   H16j-AnU6QNcuNFgPNt2Sw           pizza-lucé-downtown-minneapolis
# 3   Z9UFvaj_zeaVSg4Ta8D9qQ                    red-rabbit-minneapolis
# 4   _-DCHZV7n1LzeD6cFVpebQ                         og-zaza-roseville
# 5   khPTVPMHdaAUNOX1LVnBng           bricksworth-beer-co-minneapolis
# 6   CSmr2eaOX3SDsL5htqIynw                      boludo-minneapolis-4
# 7   OXy8tz9HWiOK_fbh29TEGg                      boludo-minneapolis-3
# 8   yUO_BhkMsv-oJdJDdi3UGw             wrecktangle-pizza-minneapolis
# 9   BzB0KtBMoml85z9FEHtZzw                    italian-butcher-savage
# 10  8jLJGrAKL90O5z98ZNQ2bQ  black-sheep-coal-fired-pizza-minneapolis
# 11  DCgcpxRiguQkyYLoX-WAMg                    good-times-minneapolis
# 12  4MaXw1ibxnsqBem43kAm_Q               pizzaria-novara-bloomington
# 13  34MfK_IGLKnDju2cyRWUhw           a-slice-of-new-york-minneapolis
# 14  XTD53AVRylnImME1acOTqg       element-wood-fire-pizza-minneapolis
# 15  SCMZp8X_XSTmiv783G-urg            elmars-new-york-pizza-plymouth
# 16  MIko91ZaMFPwcUqGkK5iUQ                  broadway-pizza-richfield
# 17  mmWrP9IOhnJWs-rPKqJ_ww     tono-pizzeria-cheesesteaks-saint-paul
# 18  5wZrNeYwR-m_EiDrWro29w           wrecktangle-pizza-minneapolis-2
# 19  9GYDp5N1RljwT9kNw326MA                 arturos-pizza-minneapolis
#
#                             name  \
# 0                  Pizzeria Lola
# 1                     Young Joni
# 2            Pizza Lucé Downtown
# 3                     Red Rabbit
# 4                        OG Zaza
# 5            Bricksworth Beer Co
# 6                         Boludo
# 7                        Boludo
# 8              Wrecktangle Pizza
# 9                Italian Butcher
# 10  Black Sheep Coal Fired Pizza
# 11                    Good Times
# 12               Pizzaria Novara
# 13           A Slice of New York
# 14       Element Wood Fire Pizza
# 15        ElMar's New York Pizza
# 16                Broadway Pizza
# 17  Tono Pizzeria + Cheesesteaks
# 18             Wrecktangle Pizza
# 19                Arturo's Pizza
#
#                                             image_url  is_closed  \
# 0   https://s3-media2.fl.yelpcdn.com/bphoto/hnnHp2...      False
# 1   https://s3-media2.fl.yelpcdn.com/bphoto/0Js61i...      False
# 2   https://s3-media2.fl.yelpcdn.com/bphoto/J48o_d...      False
# 3   https://s3-media3.fl.yelpcdn.com/bphoto/q_0dLY...      False
# 4   https://s3-media2.fl.yelpcdn.com/bphoto/4MNgRA...      False
# 5   https://s3-media3.fl.yelpcdn.com/bphoto/mRsAED...      False
# 6   https://s3-media1.fl.yelpcdn.com/bphoto/pSvuJR...      False
# 7   https://s3-media1.fl.yelpcdn.com/bphoto/tgxeHC...      False
# 8   https://s3-media3.fl.yelpcdn.com/bphoto/7qmBev...      False
# 9   https://s3-media2.fl.yelpcdn.com/bphoto/RFgr95...      False
# 10  https://s3-media2.fl.yelpcdn.com/bphoto/1XFLsW...      False
# 11  https://s3-media2.fl.yelpcdn.com/bphoto/keZl_x...      False
# 12  https://s3-media2.fl.yelpcdn.com/bphoto/ErBjm3...      False
# 13  https://s3-media2.fl.yelpcdn.com/bphoto/cEw9cQ...      False
# 14  https://s3-media2.fl.yelpcdn.com/bphoto/rpBdMY...      False
# 15  https://s3-media2.fl.yelpcdn.com/bphoto/SA723q...      False
# 16  https://s3-media3.fl.yelpcdn.com/bphoto/ahisi4...      False
# 17  https://s3-media4.fl.yelpcdn.com/bphoto/w216mY...      False
# 18  https://s3-media2.fl.yelpcdn.com/bphoto/K6kJgW...      False
# 19  https://s3-media3.fl.yelpcdn.com/bphoto/kXqlIm...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/pizzeria-lola-minneap...          1236
# 1   https://www.yelp.com/biz/young-joni-minneapoli...           909
# 2   https://www.yelp.com/biz/pizza-luc%C3%A9-downt...           680
# 3   https://www.yelp.com/biz/red-rabbit-minneapoli...           744
# 4   https://www.yelp.com/biz/og-zaza-roseville?adj...             7
# 5   https://www.yelp.com/biz/bricksworth-beer-co-m...             4
# 6   https://www.yelp.com/biz/boludo-minneapolis-4?...           105
# 7   https://www.yelp.com/biz/boludo-minneapolis-3?...           321
# 8   https://www.yelp.com/biz/wrecktangle-pizza-min...            99
# 9   https://www.yelp.com/biz/italian-butcher-savag...             2
# 10  https://www.yelp.com/biz/black-sheep-coal-fire...           587
# 11  https://www.yelp.com/biz/good-times-minneapoli...            17
# 12  https://www.yelp.com/biz/pizzaria-novara-bloom...             8
# 13  https://www.yelp.com/biz/a-slice-of-new-york-m...           143
# 14  https://www.yelp.com/biz/element-wood-fire-piz...           282
# 15  https://www.yelp.com/biz/elmars-new-york-pizza...           137
# 16  https://www.yelp.com/biz/broadway-pizza-richfi...           169
# 17  https://www.yelp.com/biz/tono-pizzeria-cheeses...            83
# 18  https://www.yelp.com/biz/wrecktangle-pizza-min...            26
# 19  https://www.yelp.com/biz/arturos-pizza-minneap...            12
#
#                                            categories  rating  \
# 0              [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 1   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 2   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 3   [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.5
# 4   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 5   [{'alias': 'brewpubs', 'title': 'Brewpubs'}, {...     4.5
# 6   [{'alias': 'argentine', 'title': 'Argentine'},...     4.5
# 7   [{'alias': 'empanadas', 'title': 'Empanadas'},...     4.5
# 8              [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 9   [{'alias': 'italian', 'title': 'Italian'}, {'a...     5.0
# 10  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 11  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     5.0
# 12  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     5.0
# 13             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 14             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 15             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 16             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 17  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 18             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 19  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
#
#                                           coordinates        transactions  \
# 0   {'latitude': 44.901815399420016, 'longitude': ...          [delivery]
# 1      {'latitude': 45.00123, 'longitude': -93.26664}          [delivery]
# 2   {'latitude': 44.9817564, 'longitude': -93.2735...          [delivery]
# 3    {'latitude': 44.983694, 'longitude': -93.271747}          [delivery]
# 4   {'latitude': 45.01285904350727, 'longitude': -...                  []
# 5   {'latitude': 44.9848362, 'longitude': -93.2761...                  []
# 6     {'latitude': 44.976956, 'longitude': -93.26202}          [delivery]
# 7   {'latitude': 44.93427172240348, 'longitude': -...          [delivery]
# 8      {'latitude': 44.98795, 'longitude': -93.27803}  [delivery, pickup]
# 9   {'latitude': 44.7425923944024, 'longitude': -9...          [delivery]
# 10  {'latitude': 44.98728104723343, 'longitude': -...  [delivery, pickup]
# 11     {'latitude': 44.93423, 'longitude': -93.28399}                  []
# 12  {'latitude': 44.85627992755595, 'longitude': -...                  []
# 13  {'latitude': 44.9589542099465, 'longitude': -9...  [delivery, pickup]
# 14  {'latitude': 44.9986018, 'longitude': -93.2676...          [delivery]
# 15      {'latitude': 45.0235, 'longitude': -93.48097}          [delivery]
# 16     {'latitude': 44.86667, 'longitude': -93.28885}          [delivery]
# 17    {'latitude': 44.93409, 'longitude': -93.167325}          [delivery]
# 18  {'latitude': 44.948183772838064, 'longitude': ...  [delivery, pickup]
# 19  {'latitude': 44.988530729766985, 'longitude': ...  [delivery, pickup]
#
#    price                                           location         phone  \
# 0     $$  {'address1': '5557 Xerxes Ave S', 'address2': ...  +16124248338
# 1     $$  {'address1': '165 13th Ave NE', 'address2': ''...  +16123455719
# 2     $$  {'address1': '119 N 4th St', 'address2': '', '...  +16123337359
# 3     $$  {'address1': '201 N Washington Ave', 'address2...  +16127678855
# 4    NaN  {'address1': '1595 MN-36', 'address2': 'Ste 10...  +16512075746
# 5    NaN  {'address1': '305 N 5th Ave', 'address2': 'Ste...  +19526575236
# 6    NaN  {'address1': '530 S 4th St', 'address2': None,...  +16124463833
# 7     $$  {'address1': '8 W 38th St', 'address2': '', 'a...  +16123535574
# 8     $$  {'address1': '729 N Washington Ave', 'address2...  +16126956525
# 9    NaN  {'address1': '14425 State Hwy 13', 'address2':...  +19528554665
# 10    $$  {'address1': '600 Washington Ave N', 'address2...  +16123422625
# 11   NaN  {'address1': '322 W 38th St', 'address2': '', ...
# 12   NaN  {'address1': '8100 26th Ave S', 'address2': ''...
# 13     $  {'address1': '2407 Nicollet Ave', 'address2': ...  +16128714334
# 14    $$  {'address1': '96 Broadway St NE', 'address2': ...  +16123793028
# 15   NaN  {'address1': '15725 37th Ave N', 'address2': '...
# 16    $$  {'address1': '7514 Lyndale Ave S', 'address2':...  +16128613402
# 17    $$  {'address1': '1580 Saint Clair Ave', 'address2...  +16512431978
# 18   NaN  {'address1': '703 W Lake St', 'address2': '', ...  +16124444420
# 19   NaN  {'address1': '18 University Ave NE', 'address2...  +16128861624
#
#      display_phone      distance
# 0   (612) 424-8338   8848.533353
# 1   (612) 345-5719   3427.201161
# 2   (612) 333-7359   1572.140788
# 3   (612) 767-8855   1677.052018
# 4   (651) 207-5746   8575.524206
# 5   (952) 657-5236   1970.249686
# 6   (612) 446-3833    703.918303
# 7   (612) 353-5574   4236.897521
# 8   (612) 695-6525   2340.875059
# 9   (952) 855-4665  26976.103221
# 10  (612) 342-2625   2173.564359
# 11                   4396.307772
# 12                  12841.252544
# 13  (612) 871-4334   1793.482349
# 14  (612) 379-3028   3167.910286
# 15                  18261.305332
# 16  (612) 861-3402  11737.081159
# 17  (651) 243-1978   8446.511339
# 18  (612) 444-4420   3254.675792
# 19  (612) 886-1624   2043.908074

# %%
## How many results total?

# %% [markdown]
# - Where is the actual data we want to save?

# %%
## How many did we get the details for?
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 20

# %% [markdown]
# - Calculate how many pages of results needed to cover the total_results

# %%
# Import additional packages for controlling our loop
import time, math
# Use math.ceil to round up for the total number of pages of results.
n_pages = math.ceil((results['total'])/ results_per_page)
n_pages
# Out:
# 85

# %%
for i in tqdm_notebook( range(1,n_pages+1)):
   # The block of code we want to TRY to run
    try:
        
        time.sleep(.2)
        
        ## Read in results in progress file and check the length
        with open(JSON_FILE, 'r') as f:
            previous_results = json.load(f)
            
        ## save number of results for to use as offset
        n_results = len(previous_results)
        
        
        ## use n_results as the OFFSET 
        results = yelp.search_query(location=location,
                                        term=term, 
                                        offset=n_results+1)

        ## append new results and save to file
        previous_results.extend(results['businesses'])

        with open(JSON_FILE,'w') as f:
            json.dump(previous_results,f)
            
    #What to do if we get an error/exception.
    except Exception as e: # saving the error message so we can print it.
        print('[!] ERROR: ',e)
# Out:
#   0%|          | 0/85 [00:00<?, ?it/s]
# [!] ERROR:  VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
# [!] ERROR:  VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
# [!] ERROR:  VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
# [!] ERROR:  VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
# [!] ERROR:  VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
# [!] ERROR:  VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
# [!] ERROR:  VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
# [!] ERROR:  VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
# [!] ERROR:  VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
# [!] ERROR:  VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
# [!] ERROR:  VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
# [!] ERROR:  VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
# [!] ERROR:  VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
# [!] ERROR:  VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
# [!] ERROR:  VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
# [!] ERROR:  VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
# [!] ERROR:  VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
# [!] ERROR:  VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
# [!] ERROR:  VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
# [!] ERROR:  VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
# [!] ERROR:  VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
# [!] ERROR:  VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
# [!] ERROR:  VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
# [!] ERROR:  VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
# [!] ERROR:  VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
# [!] ERROR:  VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
# [!] ERROR:  VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
# [!] ERROR:  VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
# [!] ERROR:  VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
# [!] ERROR:  VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
# [!] ERROR:  VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
# [!] ERROR:  VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
# [!] ERROR:  VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
# [!] ERROR:  VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
# [!] ERROR:  VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.
# [!] ERROR:  VALIDATION_ERROR: Too many results requested, limit+offset must be <= 1000.

# %% [markdown]
# ![png](Figures/Poll_531.png)

# %% [markdown]
# ## Open the Final JSON File with Pandas

# %%
df = pd.read_json(JSON_FILE)

# %%
df.head()
# Out:
#                        id                            alias  \
# 0  5Y2nekkwRrNMMSx3b-2EhA           young-joni-minneapolis
# 1  H16j-AnU6QNcuNFgPNt2Sw  pizza-lucé-downtown-minneapolis
# 2  Z9UFvaj_zeaVSg4Ta8D9qQ           red-rabbit-minneapolis
# 3  _-DCHZV7n1LzeD6cFVpebQ                og-zaza-roseville
# 4  khPTVPMHdaAUNOX1LVnBng  bricksworth-beer-co-minneapolis
#
#                   name                                          image_url  \
# 0           Young Joni  https://s3-media2.fl.yelpcdn.com/bphoto/0Js61i...
# 1  Pizza Lucé Downtown  https://s3-media2.fl.yelpcdn.com/bphoto/J48o_d...
# 2           Red Rabbit  https://s3-media3.fl.yelpcdn.com/bphoto/q_0dLY...
# 3              OG Zaza  https://s3-media2.fl.yelpcdn.com/bphoto/4MNgRA...
# 4  Bricksworth Beer Co  https://s3-media3.fl.yelpcdn.com/bphoto/mRsAED...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/young-joni-minneapoli...           909
# 1      False  https://www.yelp.com/biz/pizza-luc%C3%A9-downt...           680
# 2      False  https://www.yelp.com/biz/red-rabbit-minneapoli...           744
# 3      False  https://www.yelp.com/biz/og-zaza-roseville?adj...             7
# 4      False  https://www.yelp.com/biz/bricksworth-beer-co-m...             4
#
#                                           categories  rating  \
# 0  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 1  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 2  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.5
# 3  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 4  [{'alias': 'brewpubs', 'title': 'Brewpubs'}, {...     4.5
#
#                                          coordinates transactions price  \
# 0     {'latitude': 45.00123, 'longitude': -93.26664}   [delivery]    $$
# 1  {'latitude': 44.9817564, 'longitude': -93.2735...   [delivery]    $$
# 2   {'latitude': 44.983694, 'longitude': -93.271747}   [delivery]    $$
# 3  {'latitude': 45.01285904350727, 'longitude': -...           []   NaN
# 4  {'latitude': 44.9848362, 'longitude': -93.2761...           []   NaN
#
#                                             location         phone  \
# 0  {'address1': '165 13th Ave NE', 'address2': ''...  +16123455719
# 1  {'address1': '119 N 4th St', 'address2': '', '...  +16123337359
# 2  {'address1': '201 N Washington Ave', 'address2...  +16127678855
# 3  {'address1': '1595 MN-36', 'address2': 'Ste 10...  +16512075746
# 4  {'address1': '305 N 5th Ave', 'address2': 'Ste...  +19526575236
#
#     display_phone     distance
# 0  (612) 345-5719  3427.201161
# 1  (612) 333-7359  1572.140788
# 2  (612) 767-8855  1677.052018
# 3  (651) 207-5746  8575.524206
# 4  (952) 657-5236  1970.249686

# %%
## convert the filename to a .csv.gz
csv_file = JSON_FILE.replace('.json','.csv.gz')
csv_file
# Out:
# 'Data/Minneapolis-pizza.csv.gz'

# %%
## Save it as a compressed csv (to save space)
df.to_csv(csv_file, compression='gzip', index=False)

# %% [markdown]
# ## Bonus: compare filesize with os module's `os.path.getsize`

# %%
size_json = os.path.getsize(JSON_FILE)
size_csv_gz = os.path.getsize(JSON_FILE.replace('.json','.csv.gz'))

print(f'JSON FILE: {size_json:,} Bytes')
print(f'CSV.GZ FILE: {size_csv_gz:,} Bytes')

print(f'the csv.gz is {size_json/size_csv_gz} times smaller!')
# Out:
# JSON FILE: 961,136 Bytes
# CSV.GZ FILE: 144,664 Bytes
# the csv.gz is 6.643919703589006 times smaller!

# %% [markdown]
# ## Next Class: Processing the Results and Mapping
